# %%
# !pip install --upgrade pip setuptools wheel
# !pip install -r requirements.txt

import m12_transform_data, m22_grid_search
import pandas as pd
import mlflow
# Out:
# Requirement already satisfied: pyyaml==6.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (6.0.1)
# Collecting pandas==2.2.2 (from -r requirements.txt (line 2))
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: scikit-surprise==1.1.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.1.3)
# Requirement already satisfied: mlflow==2.12.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (2.12.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/codespace/.local/lib/python3.10/site-packages (from pandas==2.2.2->-r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.10/site-packages (from pandas==2.2.2->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas==2.2.2->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.10/site-packages (from pandas==2.2.2->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: joblib>=1.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-surprise==1.1.3->-r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: scipy>=1.3.2 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-surprise==1.1.3->-r requirements.txt (line 3)) (1.13.0)
# Requirement already satisfied: Flask<4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: docker<8,>=4.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (7.0.0)
# Requirement already satisfied: entrypoints<1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/codespace/.local/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (3.1.43)
# Requirement already satisfied: graphene<4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (3.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (7.1.0)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (3.6)
# Requirement already satisfied: matplotlib<4 in /home/codespace/.local/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (3.8.3)
# Requirement already satisfied: packaging<25 in /home/codespace/.local/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (24.0)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (4.25.3)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (15.0.2)
# Requirement already satisfied: querystring-parser<2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (1.2.4)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/codespace/.local/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (2.31.0)
# Requirement already satisfied: scikit-learn<2 in /home/codespace/.local/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (1.4.1.post1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (2.0.30)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (0.5.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /home/codespace/.local/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (3.1.3)
# Requirement already satisfied: gunicorn<23 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from mlflow==2.12.2->-r requirements.txt (line 4)) (22.0.0)
# Requirement already satisfied: Mako in /usr/local/python/3.10.13/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==2.12.2->-r requirements.txt (line 4)) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /home/codespace/.local/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==2.12.2->-r requirements.txt (line 4)) (4.10.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow==2.12.2->-r requirements.txt (line 4)) (2.0.7)
# Requirement already satisfied: Werkzeug>=3.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from Flask<4->mlflow==2.12.2->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from Flask<4->mlflow==2.12.2->-r requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from Flask<4->mlflow==2.12.2->-r requirements.txt (line 4)) (1.8.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow==2.12.2->-r requirements.txt (line 4)) (4.0.11)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from graphene<4->mlflow==2.12.2->-r requirements.txt (line 4)) (3.2.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from graphene<4->mlflow==2.12.2->-r requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: aniso8601<10,>=8 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from graphene<4->mlflow==2.12.2->-r requirements.txt (line 4)) (9.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow==2.12.2->-r requirements.txt (line 4)) (3.18.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow==2.12.2->-r requirements.txt (line 4)) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.12.2->-r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.12.2->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.12.2->-r requirements.txt (line 4)) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.12.2->-r requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.12.2->-r requirements.txt (line 4)) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib<4->mlflow==2.12.2->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.12.2->-r requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.12.2->-r requirements.txt (line 4)) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow==2.12.2->-r requirements.txt (line 4)) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn<2->mlflow==2.12.2->-r requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.12.2->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow==2.12.2->-r requirements.txt (line 4)) (5.0.1)
# Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 52.0 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
# Successfully installed pandas-2.2.2

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment("check-localhost-connection")

with mlflow.start_run():
    mlflow.log_metric("foo", 1)
    mlflow.log_metric("bar", 2)

# %%
# parameters
algorithm_name = 'MF_SVD'
cv_iterator = 'hold_out'

# %%
# get users, movies and ratings sets
df_users, df_movies, df_ratings = m12_transform_data.transform_data()

# %%
# grid search
run_summary = m22_grid_search.grid_search(
    df_ratings = df_ratings
    , algorithm_name = algorithm_name
    , cv_iterator = cv_iterator
    , measures = ['mae', 'rmse', 'mse']
)

# %%
run_summary
# Out:
#     n_factors  n_epochs  biased  init_mean  init_std_dev  lr_bu  lr_bi  lr_pu  \
# 0         300        80    True          0           0.1  0.005  0.005  0.005
# 1         300       100    True          0           0.1  0.005  0.005  0.005
# 2         300       120    True          0           0.1  0.005  0.005  0.005
# 3         400        80    True          0           0.1  0.005  0.005  0.005
# 4         400       100    True          0           0.1  0.005  0.005  0.005
# 5         400       120    True          0           0.1  0.005  0.005  0.005
# 6         500        80    True          0           0.1  0.005  0.005  0.005
# 7         500       100    True          0           0.1  0.005  0.005  0.005
# 8         500       120    True          0           0.1  0.005  0.005  0.005
# 9         600        80    True          0           0.1  0.005  0.005  0.005
# 10        600       100    True          0           0.1  0.005  0.005  0.005
# 11        600       120    True          0           0.1  0.005  0.005  0.005
#
#     lr_qi  reg_bu  ...  reg_pu  reg_qi  random_state  verbose  \
# 0   0.005    0.02  ...    0.02    0.02             0    False
# 1   0.005    0.02  ...    0.02    0.02             0    False
# 2   0.005    0.02  ...    0.02    0.02             0    False
# 3   0.005    0.02  ...    0.02    0.02             0    False
# 4   0.005    0.02  ...    0.02    0.02             0    False
# 5   0.005    0.02  ...    0.02    0.02             0    False
# 6   0.005    0.02  ...    0.02    0.02             0    False
# 7   0.005    0.02  ...    0.02    0.02             0    False
# 8   0.005    0.02  ...    0.02    0.02             0    False
# 9   0.005    0.02  ...    0.02    0.02             0    False
# 10  0.005    0.02  ...    0.02    0.02             0    False
# 11  0.005    0.02  ...    0.02    0.02             0    False
#
#     split0_test_mae  split0_test_rmse  split0_test_mse  split0_train_mae  \
# 0          0.807819          1.015318         1.030871          0.141922
# 1          0.808042          1.014500         1.029210          0.134712
# 2          0.808349          1.013943         1.028080          0.130838
# 3          0.808939          1.015445         1.031129          0.136221
# 4          0.809086          1.014602         1.029416          0.131308
# 5          0.809359          1.014021         1.028238          0.128568
# 6          0.810388          1.016364         1.032995          0.133041
# 7          0.810421          1.015488         1.031216          0.129376
# 8          0.810576          1.014870         1.029960          0.127237
# 9          0.809553          1.015369         1.030974          0.130831
# 10         0.809670          1.014530         1.029272          0.128053
# 11         0.809890          1.013953         1.028102          0.126346
#
#     split0_train_rmse  split0_train_mse
# 0            0.183163          0.033549
# 1            0.175234          0.030707
# 2            0.171210          0.029313
# 3            0.176495          0.031150
# 4            0.171279          0.029337
# 5            0.168561          0.028413
# 6            0.172753          0.029844
# 7            0.169024          0.028569
# 8            0.167012          0.027893
# 9            0.170313          0.029007
# 10           0.167592          0.028087
# 11           0.166060          0.027576
#
# [12 rows x 21 columns]

# %%
1+1==2
# Out:
# True
